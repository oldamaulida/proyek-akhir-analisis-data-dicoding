# %% [markdown]
# # Proyek Analisis Data: E-Commerce Public Dataset
# - **Nama:** Maulida Aristia Tsani
# - **Email:** oldamaulida@gmail.com
# - **ID Dicoding:** maulida_aristia

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Bagaimana perbedaan pola penyewaan sepeda antara hari libur dan hari kerja pada sepeda yang disewa per hari?
# - Bagaimana perbedaan pola penyewaan sepeda pada tahun 2011 dan 2012?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
day_bk = pd.read_csv("https://raw.githubusercontent.com/oldamaulida/proyek-akhir-analisis-data-dicoding/main/data/day.csv")
day_bk.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
hour_bk = pd.read_csv("https://raw.githubusercontent.com/oldamaulida/proyek-akhir-analisis-data-dicoding/main/data/hour.csv")
hour_bk.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# ### Assessing Data

# %%
day_bk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
day_bk.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
print("Jumlah Data Duplikat : ", day_bk.duplicated().sum())
# Out:
# Jumlah Data Duplikat :  0

# %%
day_bk.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %%
hour_bk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
hour_bk.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
print("Jumlah Data Duplikat: ", hour_bk.duplicated().sum())
# Out:
# Jumlah Data Duplikat:  0

# %%
hour_bk.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# **Mengganti tipe data dteday dari object ke datetime**

# %%
datetime_columns = ["dteday"]

for column in datetime_columns:
  day_bk[column] = pd.to_datetime(day_bk[column])

# %%
day_bk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    datetime64[ns]
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(11)
# memory usage: 91.5 KB

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %% [markdown]
# **Eksplorasi data day**

# %%
day_bk.describe(include="all")
# Out:
# <ipython-input-16-f7d588e3c36f>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   day_bk.describe(include="all")
#            instant               dteday      season          yr        mnth  \
# count   731.000000                  731  731.000000  731.000000  731.000000
# unique         NaN                  731         NaN         NaN         NaN
# top            NaN  2011-01-01 00:00:00         NaN         NaN         NaN
# freq           NaN                    1         NaN         NaN         NaN
# first          NaN  2011-01-01 00:00:00         NaN         NaN         NaN
# last           NaN  2012-12-31 00:00:00         NaN         NaN         NaN
# mean    366.000000                  NaN    2.496580    0.500684    6.519836
# ...

# %% [markdown]
# **Melihat persebaran penyewa berdasarkan holiday(hari libur)**

# %%
day_bk.groupby(by="holiday").cnt.nunique().sort_values(ascending=False)
# 0 : tidak libur ; 1 : hari libur
# Out:
# holiday
# 0    679
# 1     20
# Name: cnt, dtype: int64

# %% [markdown]
# Berdasarkan data persebaran diatas penyewa sepeda banyak menyewa sepeda pada hari yang tidak libur yang berjumlah 679 penyewa

# %% [markdown]
# **Melihat persebaran peminjam berdasarkan weekday(hari kerja)**

# %%
day_bk.groupby(by="weekday").cnt.nunique().sort_values(ascending=False)
# 0 : Minggu ; 1 : Senin ; 2 : Selasa ; 3 : Rabu ; 4 : Kamis ; 5 : Jumat ; 6 : Sabtu
# Out:
# weekday
# 0    104
# 1    104
# 2    104
# 5    104
# 3    103
# 4    103
# 6    102
# Name: cnt, dtype: int64

# %% [markdown]
# Berdasarkan data persebaran diatas penyewa sepeda banyak menyewa sepeda pada hari 0 : Minggu, 1 : Senin, 2 : Selasa, 5 : Jumat yang berjumlah 104

# %% [markdown]
# Ekplorasi Data Hour

# %%
hour_bk.describe(include="all")
# Out:
#            instant      dteday        season            yr          mnth  \
# count   17379.0000       17379  17379.000000  17379.000000  17379.000000
# unique         NaN         731           NaN           NaN           NaN
# top            NaN  2011-01-01           NaN           NaN           NaN
# freq           NaN          24           NaN           NaN           NaN
# mean     8690.0000         NaN      2.501640      0.502561      6.537775
# std      5017.0295         NaN      1.106918      0.500008      3.438776
# min         1.0000         NaN      1.000000      0.000000      1.000000
# 25%      4345.5000         NaN      2.000000      0.000000      4.000000
# 50%      8690.0000         NaN      3.000000      1.000000      7.000000
# 75%     13034.5000         NaN      3.000000      1.000000     10.000000
# max     17379.0000         NaN      4.000000      1.000000     12.000000
#
#                   hr       holiday       weekday    workingday    weathersit  \
# ...

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Bagaimana perbedaan pola peminjaman sepeda antara hari libur dan hari kerja pada sepeda yang disewa per hari?

# %%
plt.figure(figsize=(12,6))
sns.barplot(x="workingday", y="cnt", data=day_bk, palette=['darkgreen', 'brown'])
plt.title("Perbedaan Pola Penyewaan Sepeda antara Hari Libur dan Hari Kerja")
plt.xlabel("Working Day (0: Holiday, 1:Working Day)")
plt.ylabel("Total Rental Bikes(cnt)")
plt.show()
# Out:
# <ipython-input-22-6b14053ca623>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="workingday", y="cnt", data=day_bk, palette=['darkgreen', 'brown'])

# %% [markdown]
# ###Pertanyaan 2 : Bagaimana perbedaan pola penyewaan sepeda pada tahun 2011 dan 2012?

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='dteday', y='cnt', hue='yr', data=day_bk, palette=['darkgreen', 'brown'])
plt.title("Perbedaan Pola Penyewaan Sepeda antara Tahun 2011 dan 2012")
plt.xlabel("Date")
plt.ylabel("Total Rental Bike (cnt)")
plt.legend(title='Year')
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclution pertanyaan 1 : Bagaimana perbedaan pola penyewaan sepeda antara hari libur dan hari kerja pada sepeda yang disewa per hari?
#
# Berdasarkan data diatas dapat disimpulkan bahwa penyewaan sepeda banyak dilakukan pada working day(1) daripada holiday(0)
#
# - Conclution pertanyaan 2 : Bagaimana perbedaan pola penyewaan sepeda pada tahun 2011 dan 2012?
#
# Perbedaannya terlihat tidak terlalu siginifikan, tahun 2012 penyewa lebih banyak dibanding tahun 2011

# %% [markdown]
# # **RFM ANALYSIS**

# %%
rfm_df = day_bk.groupby(by="instant", as_index=False).agg({
    "dteday": "max", # mengambil tanggal order terakhir
    "cnt": ["nunique", "sum"] # menghitung jumlah peminjam sepeda
})
rfm_df.columns = ["instant", "max_tenant_timestamp", "frequency", "monetary"]

# menghitung kapan terakhir pelanggan melakukan transaksi (hari)
rfm_df["max_tenant_timestamp"] = rfm_df["max_tenant_timestamp"].dt.date
recent_date = day_bk["dteday"].dt.date.max()
rfm_df["recency"] = rfm_df["max_tenant_timestamp"].apply(lambda x: (recent_date - x).days)

rfm_df.drop("max_tenant_timestamp", axis=1, inplace=True)
rfm_df.head()
# Out:
#    instant  frequency  monetary  recency
# 0        1          1       985      730
# 1        2          1       801      729
# 2        3          1      1349      728
# 3        4          1      1562      727
# 4        5          1      1600      726

# %% [markdown]
# **Mengidentifikasi Best Penyewa**

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(30, 6))

colors = ["#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4"]

sns.barplot(y="recency", x="instant", data=rfm_df.sort_values(by="recency", ascending=True).head(5), palette=['darkgreen', 'brown'], ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("By Recency (days)", loc="center", fontsize=18)
ax[0].tick_params(axis ='x', labelsize=15)

sns.barplot(y="frequency", x="instant", data=rfm_df.sort_values(by="frequency", ascending=False).head(5), palette=['darkgreen', 'brown'], ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].set_title("By Frequency", loc="center", fontsize=18)
ax[1].tick_params(axis='x', labelsize=15)

sns.barplot(y="monetary", x="instant", data=rfm_df.sort_values(by="monetary", ascending=False).head(5), palette=['darkgreen', 'brown'], ax=ax[2])
ax[2].set_ylabel(None)
ax[2].set_xlabel(None)
ax[2].set_title("By Monetary", loc="center", fontsize=18)
ax[2].tick_params(axis='x', labelsize=15)

plt.suptitle("Best Penyewa Based on RFM Parameters (instant)", fontsize=20)
plt.show()
# Out:
# <ipython-input-27-2f5837aa8f86>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="recency", x="instant", data=rfm_df.sort_values(by="recency", ascending=True).head(5), palette=['darkgreen', 'brown'], ax=ax[0])
# <ipython-input-27-2f5837aa8f86>:5: UserWarning:
# The palette list has fewer values (2) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(y="recency", x="instant", data=rfm_df.sort_values(by="recency", ascending=True).head(5), palette=['darkgreen', 'brown'], ax=ax[0])
# <ipython-input-27-2f5837aa8f86>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %% [markdown]
# - Recency: Melihat kapan terakhir seorang penyewa melakukan transaksi.
# - Frequency: Mengidentifikasi seberapa sering seorang penyewa melakukan transaksi.
# - Monetary: parameter terakhir ini digunakan untuk mengidentifikasi seberapa besar revenue yang berasal dari customer tersebut.

# %%
day_bk.to_csv("fix_data.csv", index=False)
